# %%
import nest_asyncio
nest_asyncio.apply()

import src.socapi as socapi

# %load_ext autoreload
# %autoreload 2

# %%
client = socapi.SocAPIClient("https://admin.online-sociology.ru", "ZhironkinAA", "Mashamops1234!")

# %%
get  = await client.get_by_poll(11528)

# %%
get[-6]

# %%
from bs4 import BeautifulSoup

def strip_para(html):
    soup = BeautifulSoup(html, "html.parser")
    content = soup.get_text(separator=" ", strip=True).strip('\\n').strip().lower()
    return content

def find_demo_questions(questions, gender=True, age=True, sn=True):

    pered_param = sync def():



    for q in questions:
        title = strip_para(q["title"])
        match title:
            case "укажите ваш пол.":

# %%
quota = await client.get_quota(11528)

# %%
quota
